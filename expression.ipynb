# %% [markdown]
# <a href="https://colab.research.google.com/github/mayurgawatre01/100day-of-code/blob/main/expression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("i am "+ str(25) + " years old ")
# Out:
# i am 25 years old

# %%
myName=input("enter your name")
print('The length of your name is:')
print(len(myName))

print(len('hello') )       # Returns 5

print(len('I am happy.') ) # Returns 11
len('')             # Returns 0
# Out:
# enter your nameyashraj
# The length of your name is:
# 7
# 5
# 11
# 0

# %%
name=input("enter the name")
print("length of your digit is ",len(name))
# Out:
# enter the namemayur
# length of your digit is  5

# %%
user='101.99'
converted=round(float((user)))
print(converted)
# Out:
# 102

# %%
myage=input("")
print("my age is "+ str(int(myage)) + " in 2026 ")
# Out:
# 78
# my age is 78 in 2026

# %%
42==42.0
# Out:
# True

# %%
42.0==0000042.00
# Out:
# True

# %%
42=='42'
# Out:
# False
